# %%
import pandas as pd
import numpy as np
import datetime
import matplotlib.pyplot as plt
import matplotlib.dates as mdates
from matplotlib.dates import DateFormatter

# %%
dir_data = '../data/LISIRD/'
fn = 'nrl2_tsi_P1D.csv'
dir_out = '../figures/season/'

# %%
df = pd.read_csv(dir_data + fn)
df = df.rename(columns={df.columns[0]: "date"})
df['date'] = df['date'].astype(int)

start = datetime.datetime(1882 ,1, 1)
end = datetime.datetime(2019 , 12, 31)
df['date'] = pd.date_range(start, end, freq='1d')
df = df.set_index('date')
df
# Out:
#             irradiance (W/m^2)  uncertainty (W/m^2)
# date
# 1882-01-01         1360.807617             0.454469
# 1882-01-02         1360.843994             0.481399
# 1882-01-03         1360.739990             0.487415
# 1882-01-04         1360.852417             0.461263
# 1882-01-05         1360.623657             0.463177
# ...                        ...                  ...
# 2019-12-27         1360.664062             0.030113
# 2019-12-28         1360.693359             0.035983
# 2019-12-29         1360.655640             0.028435
# 2019-12-30         1360.665405             0.030392
# 2019-12-31         1360.637451             0.024801
#
# [50403 rows x 2 columns]

# %%
plt.rcParams["figure.figsize"] = (20, 8) # (w, h)
plt.rcParams.update({'font.size': 20})
fig, ax = plt.subplots()

plt.scatter(df.index, df.iloc[:,0], s=0.1, c = 'black',label = '')
plt.title('Naval Research Laboratory’s (NRL) solar variability model v2 (NRLTSI2) \nDaily Average of Total Solar Irradiance (TSI): 1882-2019')
plt.xticks(rotation=45)
# plt.xlabel('date') 
plt.ylabel('TSI $(W/m^2)$')
plt.gca().relim()

date_form = DateFormatter("%Y")
ax.xaxis.set_major_formatter(date_form)
ax.xaxis.set_major_locator(mdates.YearLocator(10))
plt.grid()
plt.tight_layout()
plt.savefig(dir_out+'TSI_daily_1882_2019.png')

# %%
dir_data = '../data/LISIRD/'
fn = 'tsis_tsi_24hr.csv'
dir_out = '../figures/season/'

df = pd.read_csv(dir_data + fn)
df = df.rename(columns={df.columns[0]: "date"})

start = datetime.datetime(2018 ,1, 11)
end = datetime.datetime(2020 , 12, 31)
df['date'] = pd.date_range(start, end, freq='1d')
df = df.set_index('date')


iwant = (df.iloc[:,0] > 0)
df = df[iwant]
df
# Out:
#             tsi_1au (W/m^2)  instrument_accuracy_1au (W/m^2)  \
# date
# 2018-01-11        1361.6282                           0.1898
# 2018-01-12        1361.6344                           0.1898
# 2018-01-13        1361.5984                           0.1898
# 2018-01-20        1361.6264                           0.1898
# 2018-01-22        1361.5629                           0.1898
# ...                     ...                              ...
# 2020-12-27        1361.5738                           0.2115
# 2020-12-28        1361.6112                           0.2116
# 2020-12-29        1361.7394                           0.2116
# 2020-12-30        1361.8225                           0.2116
# 2020-12-31        1361.8915                           0.2118
#
#             instrument_precision_1au (W/m^2)  \
# date
# 2018-01-11                            0.0068
# 2018-01-12                            0.0068
# 2018-01-13                            0.0068
# 2018-01-20                            0.0068
# 2018-01-22                            0.0068
# ...                                      ...
# 2020-12-27                            0.0068
# 2020-12-28                            0.0068
# 2020-12-29                            0.0068
# 2020-12-30                            0.0068
# 2020-12-31                            0.0068
#
#             solar_standard_deviation_1au (W/m^2)  \
# date
# 2018-01-11                               0.04423
# 2018-01-12                               0.07024
# 2018-01-13                               0.08029
# 2018-01-20                               0.13000
# 2018-01-22                               0.14680
# ...                                          ...
# 2020-12-27                               0.05257
# 2020-12-28                               0.05691
# 2020-12-29                               0.05964
# 2020-12-30                               0.05915
# 2020-12-31                               0.05293
#
#             measurement_uncertainty_1au (W/m^2)  tsi_true_earth (W/m^2)  \
# date
# 2018-01-11                               0.1949               1407.7706
# 2018-01-12                               0.2024               1407.6523
# 2018-01-13                               0.2061               1407.4745
# 2018-01-20                               0.2300               1406.1574
# 2018-01-22                               0.2400               1405.5329
# ...                                         ...                     ...
# 2020-12-27                               0.2179               1407.9984
# 2020-12-28                               0.2191               1408.1440
# 2020-12-29                               0.2199               1408.3605
# 2020-12-30                               0.2197               1408.5101
# 2020-12-31                               0.2183               1408.6283
#
#             instrument_accuracy_true_earth (W/m^2)  \
# date
# 2018-01-11                                  0.1962
# 2018-01-12                                  0.1962
# 2018-01-13                                  0.1962
# 2018-01-20                                  0.1960
# 2018-01-22                                  0.1959
# ...                                            ...
# 2020-12-27                                  0.2187
# 2020-12-28                                  0.2188
# 2020-12-29                                  0.2189
# 2020-12-30                                  0.2189
# 2020-12-31                                  0.2190
#
#             instrument_precision_true_earth (W/m^2)  \
# date
# 2018-01-11                                   0.0068
# 2018-01-12                                   0.0068
# 2018-01-13                                   0.0068
# 2018-01-20                                   0.0068
# 2018-01-22                                   0.0068
# ...                                             ...
# 2020-12-27                                   0.0068
# 2020-12-28                                   0.0068
# 2020-12-29                                   0.0068
# 2020-12-30                                   0.0068
# 2020-12-31                                   0.0068
#
#             solar_standard_deviation_true_earth (W/m^2)  \
# date
# 2018-01-11                                      0.04577
# 2018-01-12                                      0.07740
# 2018-01-13                                      0.08234
# 2018-01-20                                      0.14250
# 2018-01-22                                      0.16350
# ...                                                 ...
# 2020-12-27                                      0.06439
# 2020-12-28                                      0.07615
# 2020-12-29                                      0.07280
# 2020-12-30                                      0.07186
# 2020-12-31                                      0.05839
#
#             measurement_uncertainty_true_earth (W/m^2)  \
# date
# 2018-01-11                                      0.2015
# 2018-01-12                                      0.2109
# 2018-01-13                                      0.2128
# 2018-01-20                                      0.2423
# 2018-01-22                                      0.2552
# ...                                                ...
# 2020-12-27                                      0.2279
# 2020-12-28                                      0.2317
# 2020-12-29                                      0.2307
# 2020-12-30                                      0.2304
# 2020-12-31                                      0.2267
#
#             avg_measurement_date (Julian Date)  \
# date
# 2018-01-11                        2.458130e+06
# 2018-01-12                        2.458131e+06
# 2018-01-13                        2.458132e+06
# 2018-01-20                        2.458139e+06
# 2018-01-22                        2.458141e+06
# ...                                        ...
# 2020-12-27                        2.459211e+06
# 2020-12-28                        2.459212e+06
# 2020-12-29                        2.459213e+06
# 2020-12-30                        2.459214e+06
# 2020-12-31                        2.459215e+06
#
#             std_dev_measurement_date (days)  provisional_flag
# date
# 2018-01-11                           0.0064                 0
# 2018-01-12                           0.0973                 0
# 2018-01-13                           0.0975                 0
# 2018-01-20                           0.0974                 0
# 2018-01-22                           0.2535                 0
# ...                                     ...               ...
# 2020-12-27                           0.2679                 0
# 2020-12-28                           0.2902                 0
# 2020-12-29                           0.2770                 0
# 2020-12-30                           0.2906                 0
# 2020-12-31                           0.2925                 0
#
# [946 rows x 13 columns]

# %%
plt.rcParams["figure.figsize"] = (20, 8) # (w, h)
plt.rcParams.update({'font.size': 20})
fig, ax = plt.subplots()

plt.plot(df.index, df.iloc[:,0], color = 'k', marker = 'o', linestyle='dashed', linewidth=1, markersize=5)
plt.title('LASP TSIS Spectral Irradiance Monitor (SIM) \nDaily Average of Total Solar Irradiance (TSI): 2018-2020')
plt.xticks(rotation=45)
# plt.xlabel('date') 
plt.ylabel('TSI $(W/m^2)$')
plt.ylim([1361,1362])
date_form = DateFormatter("%Y-%m")
ax.xaxis.set_major_formatter(date_form)
ax.xaxis.set_major_locator(mdates.MonthLocator([1,4,7,10]))
plt.grid()
plt.tight_layout()
plt.savefig(dir_out+'TSI_daily_2018_2020.png')
