# %%
import pandas as pd
import numpy as np
import os
import sys
import datetime
import time
import math
import netCDF4 as nc

#from netCDF4 import Dataset, num2date
import matplotlib.pyplot as plt
from sklearn.ensemble import RandomForestRegressor
from sklearn.neural_network import MLPRegressor
from sklearn.model_selection import GridSearchCV, train_test_split
from sklearn.preprocessing import MinMaxScaler

import matplotlib.dates as mdates
import matplotlib.colors
import matplotlib.ticker as ticker

from pysolar.solar import *
import pytz
import shap
import pickle
import multiprocessing

#  32.5,  33.5
# -97.5, -96.5

# %%
folder = "spatial"
node_id = "10004098"
dir_out = "../figures/" + folder + "/"
dir_data = "../data/"

fn_in = dir_data + "driving_" + node_id + "_landsat_NEXRAD.csv"

# %%
df = pd.read_csv(fn_in, index_col = 'UTC')

# %%
df.head()
# Out:
#                      Illuminance     360nm     361nm     362nm     363nm  \
# UTC
# 2020-01-08 16:43:40  3849.500854  0.042302  0.042491  0.043221  0.044318
# 2020-01-08 16:43:50  2345.220551  0.032529  0.032651  0.033183  0.033997
# 2020-01-08 16:44:00  2385.540894  0.033112  0.033226  0.033758  0.034580
# 2020-01-08 16:44:10  2566.076355  0.033985  0.034098  0.034641  0.035480
# 2020-01-08 16:44:20  2944.573364  0.040020  0.040161  0.040814  0.041823
#
#                         364nm     365nm     366nm     367nm     368nm  ...  \
# UTC                                                                    ...
# 2020-01-08 16:43:40  0.045591  0.046490  0.047298  0.047995  0.048536  ...
# 2020-01-08 16:43:50  0.034946  0.035627  0.036239  0.036761  0.037158  ...
# 2020-01-08 16:44:00  0.035541  0.036231  0.036851  0.037380  0.037782  ...
# 2020-01-08 16:44:10  0.036464  0.037165  0.037798  0.038343  0.038761  ...
# 2020-01-08 16:44:20  0.043005  0.043871  0.044654  0.045327  0.045841  ...
#
#                          ROI 1km     ROI 2km      ROI 3km     ROI 4km  \
# UTC
# 2020-01-08 16:43:40  2504.286377  2554.29126  2604.296387  2654.30127
# 2020-01-08 16:43:50  2504.286377  2554.29126  2604.296387  2654.30127
# 2020-01-08 16:44:00  2504.286377  2554.29126  2604.296387  2654.30127
# 2020-01-08 16:44:10  2504.286377  2554.29126  2604.296387  2654.30127
# 2020-01-08 16:44:20  2504.286377  2554.29126  2604.296387  2654.30127
#
#                          ROI 5km      ROI 6km      ROI 7km      ROI 8km  \
# UTC
# 2020-01-08 16:43:40  2704.306396  2754.311279  2804.316162  2854.321289
# 2020-01-08 16:43:50  2704.306396  2754.311279  2804.316162  2854.321289
# 2020-01-08 16:44:00  2704.306396  2754.311279  2804.316162  2854.321289
# 2020-01-08 16:44:10  2704.306396  2754.311279  2804.316162  2854.321289
# 2020-01-08 16:44:20  2704.306396  2754.311279  2804.316162  2854.321289
#
#                          ROI 9km     ROI 10km
# UTC
# 2020-01-08 16:43:40  2904.326172  2954.331299
# 2020-01-08 16:43:50  2904.326172  2954.331299
# 2020-01-08 16:44:00  2904.326172  2954.331299
# 2020-01-08 16:44:10  2904.326172  2954.331299
# 2020-01-08 16:44:20  2904.326172  2954.331299
#
# [5 rows x 509 columns]

# %%
features = ['Zenith',
            'SR1', 'SR2', 'SR3', 'SR4',
            'reflectivity 0km', 'reflectivity 1km',
            'reflectivity 2km', 'reflectivity 3km', 'reflectivity 4km',
            'reflectivity 5km', 'reflectivity 6km', 'reflectivity 7km',
            'reflectivity 8km', 'reflectivity 9km', 'reflectivity 10km',
            'velocity 0km', 'velocity 1km', 'velocity 2km', 'velocity 3km',
            'velocity 4km', 'velocity 5km', 'velocity 6km', 'velocity 7km',
            'velocity 8km', 'velocity 9km', 'velocity 10km', 'spectrum_width 0km',
            'spectrum_width 1km', 'spectrum_width 2km', 'spectrum_width 3km',
            'spectrum_width 4km', 'spectrum_width 5km', 'spectrum_width 6km',
            'spectrum_width 7km', 'spectrum_width 8km', 'spectrum_width 9km',
            'spectrum_width 10km', 'differential_phase 0km',
            'differential_phase 1km', 'differential_phase 2km',
            'differential_phase 3km', 'differential_phase 4km',
            'differential_phase 5km', 'differential_phase 6km',
            'differential_phase 7km', 'differential_phase 8km',
            'differential_phase 9km', 'differential_phase 10km',
            'differential_reflectivity 0km', 'differential_reflectivity 1km',
            'differential_reflectivity 2km', 'differential_reflectivity 3km',
            'differential_reflectivity 4km', 'differential_reflectivity 5km',
            'differential_reflectivity 6km', 'differential_reflectivity 7km',
            'differential_reflectivity 8km', 'differential_reflectivity 9km',
            'differential_reflectivity 10km', 'cross_correlation_ratio 0km',
            'cross_correlation_ratio 1km', 'cross_correlation_ratio 2km',
            'cross_correlation_ratio 3km', 'cross_correlation_ratio 4km',
            'cross_correlation_ratio 5km', 'cross_correlation_ratio 6km',
            'cross_correlation_ratio 7km', 'cross_correlation_ratio 8km',
            'cross_correlation_ratio 9km', 'cross_correlation_ratio 10km',
            'ROI 0km', 'ROI 1km', 'ROI 2km', 'ROI 3km', 'ROI 4km', 'ROI 5km',
            'ROI 6km', 'ROI 7km', 'ROI 8km', 'ROI 9km', 'ROI 10km']

target = 'Illuminance'

# %%
X = df[features]
y = df[target]
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=0)

# %%
RANDOM_STATE = 42
n_jobs = multiprocessing.cpu_count()

# %%
start_time = time.time()

# Random Forest Model, grid search to find best parameter
rfr = RandomForestRegressor(random_state = RANDOM_STATE, oob_score=True, n_jobs = n_jobs)
param_grid = {'max_depth': [10,20,30,40,50],
              'n_estimators': [30,40,50,60,80,100],
              'min_samples_split': [10, 20, 50],
              'min_samples_leaf': [1, 5, 10],
              'max_features': ['auto'],
              'max_samples': [len(X_train)//10]}
CV_rfr = GridSearchCV(estimator = rfr, param_grid = param_grid, cv =2, verbose = 3)

CV_rfr.fit(X_train, y_train)
print(CV_rfr.best_params_)
print(CV_rfr.best_score_)

print("--- %s seconds ---" % (time.time() - start_time))
# Out:
# Fitting 2 folds for each of 270 candidates, totalling 540 fits
# [CV 1/2] END max_depth=10, max_features=auto, max_samples=2209, min_samples_leaf=1, min_samples_split=10, n_estimators=30; total time=   2.2s
# [CV 2/2] END max_depth=10, max_features=auto, max_samples=2209, min_samples_leaf=1, min_samples_split=10, n_estimators=30; total time=   0.3s
# [CV 1/2] END max_depth=10, max_features=auto, max_samples=2209, min_samples_leaf=1, min_samples_split=10, n_estimators=40; total time=   0.4s
# [CV 2/2] END max_depth=10, max_features=auto, max_samples=2209, min_samples_leaf=1, min_samples_split=10, n_estimators=40; total time=   0.4s
# [CV 1/2] END max_depth=10, max_features=auto, max_samples=2209, min_samples_leaf=1, min_samples_split=10, n_estimators=50; total time=   0.4s
# [CV 2/2] END max_depth=10, max_features=auto, max_samples=2209, min_samples_leaf=1, min_samples_split=10, n_estimators=50; total time=   0.4s
# [CV 1/2] END max_depth=10, max_features=auto, max_samples=2209, min_samples_leaf=1, min_samples_split=10, n_estimators=60; total time=   0.6s
# [CV 2/2] END max_depth=10, max_features=auto, max_samples=2209, min_samples_leaf=1, min_samples_split=10, n_estimators=60; total time=   0.5s
# [CV 1/2] END max_depth=10, max_features=auto, max_samples=2209, min_samples_leaf=1, min_samples_split=10, n_estimators=80; total time=   0.7s
# [CV 2/2] END max_depth=10, max_features=auto, max_samples=2209, min_samples_leaf=1, min_samples_split=10, n_estimators=80; total time=   0.7s
# [CV 1/2] END max_depth=10, max_features=auto, max_samples=2209, min_samples_leaf=1, min_samples_split=10, n_estimators=100; total time=   0.8s
# [CV 2/2] END max_depth=10, max_features=auto, max_samples=2209, min_samples_leaf=1, min_samples_split=10, n_estimators=100; total time=   0.8s
# [CV 1/2] END max_depth=10, max_features=auto, max_samples=2209, min_samples_leaf=1, min_samples_split=20, n_estimators=30; total time=   0.3s
# [CV 2/2] END max_depth=10, max_features=auto, max_samples=2209, min_samples_leaf=1, min_samples_split=20, n_estimators=30; total time=   0.3s
# [CV 1/2] END max_depth=10, max_features=auto, max_samples=2209, min_samples_leaf=1, min_samples_split=20, n_estimators=40; total time=   0.4s
# [CV 2/2] END max_depth=10, max_features=auto, max_samples=2209, min_samples_leaf=1, min_samples_split=20, n_estimators=40; total time=   0.3s
# [CV 1/2] END max_depth=10, max_features=auto, max_samples=2209, min_samples_leaf=1, min_samples_split=20, n_estimators=50; total time=   0.4s
# [CV 2/2] END max_depth=10, max_features=auto, max_samples=2209, min_samples_leaf=1, min_samples_split=20, n_estimators=50; total time=   0.4s
# [CV 1/2] END max_depth=10, max_features=auto, max_samples=2209, min_samples_leaf=1, min_samples_split=20, n_estimators=60; total time=   0.5s
# [CV 2/2] END max_depth=10, max_features=auto, max_samples=2209, min_samples_leaf=1, min_samples_split=20, n_estimators=60; total time=   0.5s
# [CV 1/2] END max_depth=10, max_features=auto, max_samples=2209, min_samples_leaf=1, min_samples_split=20, n_estimators=80; total time=   0.7s
# [CV 2/2] END max_depth=10, max_features=auto, max_samples=2209, min_samples_leaf=1, min_samples_split=20, n_estimators=80; total time=   0.7s
# [CV 1/2] END max_depth=10, max_features=auto, max_samples=2209, min_samples_leaf=1, min_samples_split=20, n_estimators=100; total time=   0.8s
# [CV 2/2] END max_depth=10, max_features=auto, max_samples=2209, min_samples_leaf=1, min_samples_split=20, n_estimators=100; total time=   0.8s
# [CV 1/2] END max_depth=10, max_features=auto, max_samples=2209, min_samples_leaf=1, min_samples_split=50, n_estimators=30; total time=   0.3s
# [CV 2/2] END max_depth=10, max_features=auto, max_samples=2209, min_samples_leaf=1, min_samples_split=50, n_estimators=30; total time=   0.3s
# [CV 1/2] END max_depth=10, max_features=auto, max_samples=2209, min_samples_leaf=1, min_samples_split=50, n_estimators=40; total time=   0.3s
# [CV 2/2] END max_depth=10, max_features=auto, max_samples=2209, min_samples_leaf=1, min_samples_split=50, n_estimators=40; total time=   0.4s
# [CV 1/2] END max_depth=10, max_features=auto, max_samples=2209, min_samples_leaf=1, min_samples_split=50, n_estimators=50; total time=   0.4s
# [CV 2/2] END max_depth=10, max_features=auto, max_samples=2209, min_samples_leaf=1, min_samples_split=50, n_estimators=50; total time=   0.4s
# [CV 1/2] END max_depth=10, max_features=auto, max_samples=2209, min_samples_leaf=1, min_samples_split=50, n_estimators=60; total time=   0.5s
# [CV 2/2] END max_depth=10, max_features=auto, max_samples=2209, min_samples_leaf=1, min_samples_split=50, n_estimators=60; total time=   0.5s
# [CV 1/2] END max_depth=10, max_features=auto, max_samples=2209, min_samples_leaf=1, min_samples_split=50, n_estimators=80; total time=   0.6s
# [CV 2/2] END max_depth=10, max_features=auto, max_samples=2209, min_samples_leaf=1, min_samples_split=50, n_estimators=80; total time=   0.6s
# [CV 1/2] END max_depth=10, max_features=auto, max_samples=2209, min_samples_leaf=1, min_samples_split=50, n_estimators=100; total time=   0.8s
# [CV 2/2] END max_depth=10, max_features=auto, max_samples=2209, min_samples_leaf=1, min_samples_split=50, n_estimators=100; total time=   0.8s
# [CV 1/2] END max_depth=10, max_features=auto, max_samples=2209, min_samples_leaf=5, min_samples_split=10, n_estimators=30; total time=   0.3s
# [CV 2/2] END max_depth=10, max_features=auto, max_samples=2209, min_samples_leaf=5, min_samples_split=10, n_estimators=30; total time=   0.3s
# [CV 1/2] END max_depth=10, max_features=auto, max_samples=2209, min_samples_leaf=5, min_samples_split=10, n_estimators=40; total time=   0.4s
# [CV 2/2] END max_depth=10, max_features=auto, max_samples=2209, min_samples_leaf=5, min_samples_split=10, n_estimators=40; total time=   0.4s
# [CV 1/2] END max_depth=10, max_features=auto, max_samples=2209, min_samples_leaf=5, min_samples_split=10, n_estimators=50; total time=   0.4s
# [CV 2/2] END max_depth=10, max_features=auto, max_samples=2209, min_samples_leaf=5, min_samples_split=10, n_estimators=50; total time=   0.5s
# [CV 1/2] END max_depth=10, max_features=auto, max_samples=2209, min_samples_leaf=5, min_samples_split=10, n_estimators=60; total time=   0.5s
# [CV 2/2] END max_depth=10, max_features=auto, max_samples=2209, min_samples_leaf=5, min_samples_split=10, n_estimators=60; total time=   0.5s
# [CV 1/2] END max_depth=10, max_features=auto, max_samples=2209, min_samples_leaf=5, min_samples_split=10, n_estimators=80; total time=   0.7s
# [CV 2/2] END max_depth=10, max_features=auto, max_samples=2209, min_samples_leaf=5, min_samples_split=10, n_estimators=80; total time=   0.7s
# [CV 1/2] END max_depth=10, max_features=auto, max_samples=2209, min_samples_leaf=5, min_samples_split=10, n_estimators=100; total time=   0.8s
# [CV 2/2] END max_depth=10, max_features=auto, max_samples=2209, min_samples_leaf=5, min_samples_split=10, n_estimators=100; total time=   0.8s
# [CV 1/2] END max_depth=10, max_features=auto, max_samples=2209, min_samples_leaf=5, min_samples_split=20, n_estimators=30; total time=   0.3s
# [CV 2/2] END max_depth=10, max_features=auto, max_samples=2209, min_samples_leaf=5, min_samples_split=20, n_estimators=30; total time=   0.3s
# [CV 1/2] END max_depth=10, max_features=auto, max_samples=2209, min_samples_leaf=5, min_samples_split=20, n_estimators=40; total time=   0.3s
# [CV 2/2] END max_depth=10, max_features=auto, max_samples=2209, min_samples_leaf=5, min_samples_split=20, n_estimators=40; total time=   0.3s
# [CV 1/2] END max_depth=10, max_features=auto, max_samples=2209, min_samples_leaf=5, min_samples_split=20, n_estimators=50; total time=   0.4s
# [CV 2/2] END max_depth=10, max_features=auto, max_samples=2209, min_samples_leaf=5, min_samples_split=20, n_estimators=50; total time=   0.4s
# [CV 1/2] END max_depth=10, max_features=auto, max_samples=2209, min_samples_leaf=5, min_samples_split=20, n_estimators=60; total time=   0.5s
# [CV 2/2] END max_depth=10, max_features=auto, max_samples=2209, min_samples_leaf=5, min_samples_split=20, n_estimators=60; total time=   0.5s
# [CV 1/2] END max_depth=10, max_features=auto, max_samples=2209, min_samples_leaf=5, min_samples_split=20, n_estimators=80; total time=   0.7s
# [CV 2/2] END max_depth=10, max_features=auto, max_samples=2209, min_samples_leaf=5, min_samples_split=20, n_estimators=80; total time=   0.6s
# [CV 1/2] END max_depth=10, max_features=auto, max_samples=2209, min_samples_leaf=5, min_samples_split=20, n_estimators=100; total time=   0.8s
# [CV 2/2] END max_depth=10, max_features=auto, max_samples=2209, min_samples_leaf=5, min_samples_split=20, n_estimators=100; total time=   0.8s
# [CV 1/2] END max_depth=10, max_features=auto, max_samples=2209, min_samples_leaf=5, min_samples_split=50, n_estimators=30; total time=   0.3s
# [CV 2/2] END max_depth=10, max_features=auto, max_samples=2209, min_samples_leaf=5, min_samples_split=50, n_estimators=30; total time=   0.3s
# [CV 1/2] END max_depth=10, max_features=auto, max_samples=2209, min_samples_leaf=5, min_samples_split=50, n_estimators=40; total time=   0.3s
# [CV 2/2] END max_depth=10, max_features=auto, max_samples=2209, min_samples_leaf=5, min_samples_split=50, n_estimators=40; total time=   0.4s
# [CV 1/2] END max_depth=10, max_features=auto, max_samples=2209, min_samples_leaf=5, min_samples_split=50, n_estimators=50; total time=   0.4s
# [CV 2/2] END max_depth=10, max_features=auto, max_samples=2209, min_samples_leaf=5, min_samples_split=50, n_estimators=50; total time=   0.4s
# [CV 1/2] END max_depth=10, max_features=auto, max_samples=2209, min_samples_leaf=5, min_samples_split=50, n_estimators=60; total time=   0.5s
# [CV 2/2] END max_depth=10, max_features=auto, max_samples=2209, min_samples_leaf=5, min_samples_split=50, n_estimators=60; total time=   0.5s
# [CV 1/2] END max_depth=10, max_features=auto, max_samples=2209, min_samples_leaf=5, min_samples_split=50, n_estimators=80; total time=   0.6s
# [CV 2/2] END max_depth=10, max_features=auto, max_samples=2209, min_samples_leaf=5, min_samples_split=50, n_estimators=80; total time=   0.6s
# [CV 1/2] END max_depth=10, max_features=auto, max_samples=2209, min_samples_leaf=5, min_samples_split=50, n_estimators=100; total time=   0.7s
# [CV 2/2] END max_depth=10, max_features=auto, max_samples=2209, min_samples_leaf=5, min_samples_split=50, n_estimators=100; total time=   0.7s
# [CV 1/2] END max_depth=10, max_features=auto, max_samples=2209, min_samples_leaf=10, min_samples_split=10, n_estimators=30; total time=   0.3s
# [CV 2/2] END max_depth=10, max_features=auto, max_samples=2209, min_samples_leaf=10, min_samples_split=10, n_estimators=30; total time=   0.3s
# [CV 1/2] END max_depth=10, max_features=auto, max_samples=2209, min_samples_leaf=10, min_samples_split=10, n_estimators=40; total time=   0.3s
# [CV 2/2] END max_depth=10, max_features=auto, max_samples=2209, min_samples_leaf=10, min_samples_split=10, n_estimators=40; total time=   0.3s
# [CV 1/2] END max_depth=10, max_features=auto, max_samples=2209, min_samples_leaf=10, min_samples_split=10, n_estimators=50; total time=   0.4s
# [CV 2/2] END max_depth=10, max_features=auto, max_samples=2209, min_samples_leaf=10, min_samples_split=10, n_estimators=50; total time=   0.4s
# [CV 1/2] END max_depth=10, max_features=auto, max_samples=2209, min_samples_leaf=10, min_samples_split=10, n_estimators=60; total time=   0.5s
# [CV 2/2] END max_depth=10, max_features=auto, max_samples=2209, min_samples_leaf=10, min_samples_split=10, n_estimators=60; total time=   0.5s
# [CV 1/2] END max_depth=10, max_features=auto, max_samples=2209, min_samples_leaf=10, min_samples_split=10, n_estimators=80; total time=   0.6s
# [CV 2/2] END max_depth=10, max_features=auto, max_samples=2209, min_samples_leaf=10, min_samples_split=10, n_estimators=80; total time=   0.6s
# [CV 1/2] END max_depth=10, max_features=auto, max_samples=2209, min_samples_leaf=10, min_samples_split=10, n_estimators=100; total time=   0.7s
# [CV 2/2] END max_depth=10, max_features=auto, max_samples=2209, min_samples_leaf=10, min_samples_split=10, n_estimators=100; total time=   0.8s
# [CV 1/2] END max_depth=10, max_features=auto, max_samples=2209, min_samples_leaf=10, min_samples_split=20, n_estimators=30; total time=   0.3s
# [CV 2/2] END max_depth=10, max_features=auto, max_samples=2209, min_samples_leaf=10, min_samples_split=20, n_estimators=30; total time=   0.3s
# [CV 1/2] END max_depth=10, max_features=auto, max_samples=2209, min_samples_leaf=10, min_samples_split=20, n_estimators=40; total time=   0.3s
# [CV 2/2] END max_depth=10, max_features=auto, max_samples=2209, min_samples_leaf=10, min_samples_split=20, n_estimators=40; total time=   0.4s
# [CV 1/2] END max_depth=10, max_features=auto, max_samples=2209, min_samples_leaf=10, min_samples_split=20, n_estimators=50; total time=   0.5s
# [CV 2/2] END max_depth=10, max_features=auto, max_samples=2209, min_samples_leaf=10, min_samples_split=20, n_estimators=50; total time=   0.4s
# [CV 1/2] END max_depth=10, max_features=auto, max_samples=2209, min_samples_leaf=10, min_samples_split=20, n_estimators=60; total time=   0.5s
# [CV 2/2] END max_depth=10, max_features=auto, max_samples=2209, min_samples_leaf=10, min_samples_split=20, n_estimators=60; total time=   0.5s
# [CV 1/2] END max_depth=10, max_features=auto, max_samples=2209, min_samples_leaf=10, min_samples_split=20, n_estimators=80; total time=   0.6s
# [CV 2/2] END max_depth=10, max_features=auto, max_samples=2209, min_samples_leaf=10, min_samples_split=20, n_estimators=80; total time=   0.6s
# [CV 1/2] END max_depth=10, max_features=auto, max_samples=2209, min_samples_leaf=10, min_samples_split=20, n_estimators=100; total time=   0.8s
# [CV 2/2] END max_depth=10, max_features=auto, max_samples=2209, min_samples_leaf=10, min_samples_split=20, n_estimators=100; total time=   0.8s
# [CV 1/2] END max_depth=10, max_features=auto, max_samples=2209, min_samples_leaf=10, min_samples_split=50, n_estimators=30; total time=   0.3s
# [CV 2/2] END max_depth=10, max_features=auto, max_samples=2209, min_samples_leaf=10, min_samples_split=50, n_estimators=30; total time=   0.3s
# [CV 1/2] END max_depth=10, max_features=auto, max_samples=2209, min_samples_leaf=10, min_samples_split=50, n_estimators=40; total time=   0.3s
# [CV 2/2] END max_depth=10, max_features=auto, max_samples=2209, min_samples_leaf=10, min_samples_split=50, n_estimators=40; total time=   0.4s
# [CV 1/2] END max_depth=10, max_features=auto, max_samples=2209, min_samples_leaf=10, min_samples_split=50, n_estimators=50; total time=   0.4s
# [CV 2/2] END max_depth=10, max_features=auto, max_samples=2209, min_samples_leaf=10, min_samples_split=50, n_estimators=50; total time=   0.4s
# [CV 1/2] END max_depth=10, max_features=auto, max_samples=2209, min_samples_leaf=10, min_samples_split=50, n_estimators=60; total time=   0.5s
# [CV 2/2] END max_depth=10, max_features=auto, max_samples=2209, min_samples_leaf=10, min_samples_split=50, n_estimators=60; total time=   0.5s
# [CV 1/2] END max_depth=10, max_features=auto, max_samples=2209, min_samples_leaf=10, min_samples_split=50, n_estimators=80; total time=   0.6s
# [CV 2/2] END max_depth=10, max_features=auto, max_samples=2209, min_samples_leaf=10, min_samples_split=50, n_estimators=80; total time=   0.6s
# [CV 1/2] END max_depth=10, max_features=auto, max_samples=2209, min_samples_leaf=10, min_samples_split=50, n_estimators=100; total time=   0.8s
# [CV 2/2] END max_depth=10, max_features=auto, max_samples=2209, min_samples_leaf=10, min_samples_split=50, n_estimators=100; total time=   0.8s
# [CV 1/2] END max_depth=20, max_features=auto, max_samples=2209, min_samples_leaf=1, min_samples_split=10, n_estimators=30; total time=   0.4s
# [CV 2/2] END max_depth=20, max_features=auto, max_samples=2209, min_samples_leaf=1, min_samples_split=10, n_estimators=30; total time=   0.4s
# [CV 1/2] END max_depth=20, max_features=auto, max_samples=2209, min_samples_leaf=1, min_samples_split=10, n_estimators=40; total time=   0.5s
# [CV 2/2] END max_depth=20, max_features=auto, max_samples=2209, min_samples_leaf=1, min_samples_split=10, n_estimators=40; total time=   0.4s
# [CV 1/2] END max_depth=20, max_features=auto, max_samples=2209, min_samples_leaf=1, min_samples_split=10, n_estimators=50; total time=   0.6s
# [CV 2/2] END max_depth=20, max_features=auto, max_samples=2209, min_samples_leaf=1, min_samples_split=10, n_estimators=50; total time=   0.5s
# [CV 1/2] END max_depth=20, max_features=auto, max_samples=2209, min_samples_leaf=1, min_samples_split=10, n_estimators=60; total time=   0.6s
# [CV 2/2] END max_depth=20, max_features=auto, max_samples=2209, min_samples_leaf=1, min_samples_split=10, n_estimators=60; total time=   0.6s
# [CV 1/2] END max_depth=20, max_features=auto, max_samples=2209, min_samples_leaf=1, min_samples_split=10, n_estimators=80; total time=   0.8s
# [CV 2/2] END max_depth=20, max_features=auto, max_samples=2209, min_samples_leaf=1, min_samples_split=10, n_estimators=80; total time=   0.9s
# [CV 1/2] END max_depth=20, max_features=auto, max_samples=2209, min_samples_leaf=1, min_samples_split=10, n_estimators=100; total time=   1.0s
# [CV 2/2] END max_depth=20, max_features=auto, max_samples=2209, min_samples_leaf=1, min_samples_split=10, n_estimators=100; total time=   1.0s
# [CV 1/2] END max_depth=20, max_features=auto, max_samples=2209, min_samples_leaf=1, min_samples_split=20, n_estimators=30; total time=   0.3s
# [CV 2/2] END max_depth=20, max_features=auto, max_samples=2209, min_samples_leaf=1, min_samples_split=20, n_estimators=30; total time=   0.3s
# [CV 1/2] END max_depth=20, max_features=auto, max_samples=2209, min_samples_leaf=1, min_samples_split=20, n_estimators=40; total time=   0.4s
# [CV 2/2] END max_depth=20, max_features=auto, max_samples=2209, min_samples_leaf=1, min_samples_split=20, n_estimators=40; total time=   0.4s
# [CV 1/2] END max_depth=20, max_features=auto, max_samples=2209, min_samples_leaf=1, min_samples_split=20, n_estimators=50; total time=   0.5s
# [CV 2/2] END max_depth=20, max_features=auto, max_samples=2209, min_samples_leaf=1, min_samples_split=20, n_estimators=50; total time=   0.5s
# [CV 1/2] END max_depth=20, max_features=auto, max_samples=2209, min_samples_leaf=1, min_samples_split=20, n_estimators=60; total time=   0.6s
# [CV 2/2] END max_depth=20, max_features=auto, max_samples=2209, min_samples_leaf=1, min_samples_split=20, n_estimators=60; total time=   0.6s
# [CV 1/2] END max_depth=20, max_features=auto, max_samples=2209, min_samples_leaf=1, min_samples_split=20, n_estimators=80; total time=   0.8s
# [CV 2/2] END max_depth=20, max_features=auto, max_samples=2209, min_samples_leaf=1, min_samples_split=20, n_estimators=80; total time=   0.8s
# [CV 1/2] END max_depth=20, max_features=auto, max_samples=2209, min_samples_leaf=1, min_samples_split=20, n_estimators=100; total time=   0.9s
# [CV 2/2] END max_depth=20, max_features=auto, max_samples=2209, min_samples_leaf=1, min_samples_split=20, n_estimators=100; total time=   1.0s
# [CV 1/2] END max_depth=20, max_features=auto, max_samples=2209, min_samples_leaf=1, min_samples_split=50, n_estimators=30; total time=   0.3s
# [CV 2/2] END max_depth=20, max_features=auto, max_samples=2209, min_samples_leaf=1, min_samples_split=50, n_estimators=30; total time=   0.3s
# [CV 1/2] END max_depth=20, max_features=auto, max_samples=2209, min_samples_leaf=1, min_samples_split=50, n_estimators=40; total time=   0.4s
# [CV 2/2] END max_depth=20, max_features=auto, max_samples=2209, min_samples_leaf=1, min_samples_split=50, n_estimators=40; total time=   0.4s
# [CV 1/2] END max_depth=20, max_features=auto, max_samples=2209, min_samples_leaf=1, min_samples_split=50, n_estimators=50; total time=   0.5s
# [CV 2/2] END max_depth=20, max_features=auto, max_samples=2209, min_samples_leaf=1, min_samples_split=50, n_estimators=50; total time=   0.5s
# [CV 1/2] END max_depth=20, max_features=auto, max_samples=2209, min_samples_leaf=1, min_samples_split=50, n_estimators=60; total time=   0.5s
# [CV 2/2] END max_depth=20, max_features=auto, max_samples=2209, min_samples_leaf=1, min_samples_split=50, n_estimators=60; total time=   0.5s
# [CV 1/2] END max_depth=20, max_features=auto, max_samples=2209, min_samples_leaf=1, min_samples_split=50, n_estimators=80; total time=   0.7s
# [CV 2/2] END max_depth=20, max_features=auto, max_samples=2209, min_samples_leaf=1, min_samples_split=50, n_estimators=80; total time=   0.7s
# [CV 1/2] END max_depth=20, max_features=auto, max_samples=2209, min_samples_leaf=1, min_samples_split=50, n_estimators=100; total time=   0.9s
# [CV 2/2] END max_depth=20, max_features=auto, max_samples=2209, min_samples_leaf=1, min_samples_split=50, n_estimators=100; total time=   0.9s
# [CV 1/2] END max_depth=20, max_features=auto, max_samples=2209, min_samples_leaf=5, min_samples_split=10, n_estimators=30; total time=   0.3s
# [CV 2/2] END max_depth=20, max_features=auto, max_samples=2209, min_samples_leaf=5, min_samples_split=10, n_estimators=30; total time=   0.4s
# [CV 1/2] END max_depth=20, max_features=auto, max_samples=2209, min_samples_leaf=5, min_samples_split=10, n_estimators=40; total time=   0.4s
# [CV 2/2] END max_depth=20, max_features=auto, max_samples=2209, min_samples_leaf=5, min_samples_split=10, n_estimators=40; total time=   0.5s
# [CV 1/2] END max_depth=20, max_features=auto, max_samples=2209, min_samples_leaf=5, min_samples_split=10, n_estimators=50; total time=   0.5s
# [CV 2/2] END max_depth=20, max_features=auto, max_samples=2209, min_samples_leaf=5, min_samples_split=10, n_estimators=50; total time=   0.6s
# [CV 1/2] END max_depth=20, max_features=auto, max_samples=2209, min_samples_leaf=5, min_samples_split=10, n_estimators=60; total time=   0.6s
# [CV 2/2] END max_depth=20, max_features=auto, max_samples=2209, min_samples_leaf=5, min_samples_split=10, n_estimators=60; total time=   0.6s
# [CV 1/2] END max_depth=20, max_features=auto, max_samples=2209, min_samples_leaf=5, min_samples_split=10, n_estimators=80; total time=   0.8s
# [CV 2/2] END max_depth=20, max_features=auto, max_samples=2209, min_samples_leaf=5, min_samples_split=10, n_estimators=80; total time=   0.8s
# [CV 1/2] END max_depth=20, max_features=auto, max_samples=2209, min_samples_leaf=5, min_samples_split=10, n_estimators=100; total time=   1.0s
# [CV 2/2] END max_depth=20, max_features=auto, max_samples=2209, min_samples_leaf=5, min_samples_split=10, n_estimators=100; total time=   1.0s
# [CV 1/2] END max_depth=20, max_features=auto, max_samples=2209, min_samples_leaf=5, min_samples_split=20, n_estimators=30; total time=   0.3s
# [CV 2/2] END max_depth=20, max_features=auto, max_samples=2209, min_samples_leaf=5, min_samples_split=20, n_estimators=30; total time=   0.3s
# [CV 1/2] END max_depth=20, max_features=auto, max_samples=2209, min_samples_leaf=5, min_samples_split=20, n_estimators=40; total time=   0.4s
# [CV 2/2] END max_depth=20, max_features=auto, max_samples=2209, min_samples_leaf=5, min_samples_split=20, n_estimators=40; total time=   0.4s
# [CV 1/2] END max_depth=20, max_features=auto, max_samples=2209, min_samples_leaf=5, min_samples_split=20, n_estimators=50; total time=   0.5s
# [CV 2/2] END max_depth=20, max_features=auto, max_samples=2209, min_samples_leaf=5, min_samples_split=20, n_estimators=50; total time=   0.5s
# [CV 1/2] END max_depth=20, max_features=auto, max_samples=2209, min_samples_leaf=5, min_samples_split=20, n_estimators=60; total time=   0.6s
# [CV 2/2] END max_depth=20, max_features=auto, max_samples=2209, min_samples_leaf=5, min_samples_split=20, n_estimators=60; total time=   0.6s
# [CV 1/2] END max_depth=20, max_features=auto, max_samples=2209, min_samples_leaf=5, min_samples_split=20, n_estimators=80; total time=   0.8s
# [CV 2/2] END max_depth=20, max_features=auto, max_samples=2209, min_samples_leaf=5, min_samples_split=20, n_estimators=80; total time=   0.8s
# [CV 1/2] END max_depth=20, max_features=auto, max_samples=2209, min_samples_leaf=5, min_samples_split=20, n_estimators=100; total time=   0.9s
# [CV 2/2] END max_depth=20, max_features=auto, max_samples=2209, min_samples_leaf=5, min_samples_split=20, n_estimators=100; total time=   0.9s
# [CV 1/2] END max_depth=20, max_features=auto, max_samples=2209, min_samples_leaf=5, min_samples_split=50, n_estimators=30; total time=   0.3s
# [CV 2/2] END max_depth=20, max_features=auto, max_samples=2209, min_samples_leaf=5, min_samples_split=50, n_estimators=30; total time=   0.3s
# [CV 1/2] END max_depth=20, max_features=auto, max_samples=2209, min_samples_leaf=5, min_samples_split=50, n_estimators=40; total time=   0.4s
# [CV 2/2] END max_depth=20, max_features=auto, max_samples=2209, min_samples_leaf=5, min_samples_split=50, n_estimators=40; total time=   0.4s
# [CV 1/2] END max_depth=20, max_features=auto, max_samples=2209, min_samples_leaf=5, min_samples_split=50, n_estimators=50; total time=   0.5s
# [CV 2/2] END max_depth=20, max_features=auto, max_samples=2209, min_samples_leaf=5, min_samples_split=50, n_estimators=50; total time=   0.5s
# [CV 1/2] END max_depth=20, max_features=auto, max_samples=2209, min_samples_leaf=5, min_samples_split=50, n_estimators=60; total time=   0.5s
# [CV 2/2] END max_depth=20, max_features=auto, max_samples=2209, min_samples_leaf=5, min_samples_split=50, n_estimators=60; total time=   0.5s
# [CV 1/2] END max_depth=20, max_features=auto, max_samples=2209, min_samples_leaf=5, min_samples_split=50, n_estimators=80; total time=   0.7s
# [CV 2/2] END max_depth=20, max_features=auto, max_samples=2209, min_samples_leaf=5, min_samples_split=50, n_estimators=80; total time=   0.7s
# [CV 1/2] END max_depth=20, max_features=auto, max_samples=2209, min_samples_leaf=5, min_samples_split=50, n_estimators=100; total time=   0.9s
# [CV 2/2] END max_depth=20, max_features=auto, max_samples=2209, min_samples_leaf=5, min_samples_split=50, n_estimators=100; total time=   0.9s
# [CV 1/2] END max_depth=20, max_features=auto, max_samples=2209, min_samples_leaf=10, min_samples_split=10, n_estimators=30; total time=   0.3s
# [CV 2/2] END max_depth=20, max_features=auto, max_samples=2209, min_samples_leaf=10, min_samples_split=10, n_estimators=30; total time=   0.3s
# [CV 1/2] END max_depth=20, max_features=auto, max_samples=2209, min_samples_leaf=10, min_samples_split=10, n_estimators=40; total time=   0.5s
# [CV 2/2] END max_depth=20, max_features=auto, max_samples=2209, min_samples_leaf=10, min_samples_split=10, n_estimators=40; total time=   0.4s
# [CV 1/2] END max_depth=20, max_features=auto, max_samples=2209, min_samples_leaf=10, min_samples_split=10, n_estimators=50; total time=   0.6s
# [CV 2/2] END max_depth=20, max_features=auto, max_samples=2209, min_samples_leaf=10, min_samples_split=10, n_estimators=50; total time=   0.6s
# [CV 1/2] END max_depth=20, max_features=auto, max_samples=2209, min_samples_leaf=10, min_samples_split=10, n_estimators=60; total time=   0.6s
# [CV 2/2] END max_depth=20, max_features=auto, max_samples=2209, min_samples_leaf=10, min_samples_split=10, n_estimators=60; total time=   0.6s
# [CV 1/2] END max_depth=20, max_features=auto, max_samples=2209, min_samples_leaf=10, min_samples_split=10, n_estimators=80; total time=   0.8s
# [CV 2/2] END max_depth=20, max_features=auto, max_samples=2209, min_samples_leaf=10, min_samples_split=10, n_estimators=80; total time=   0.8s
# [CV 1/2] END max_depth=20, max_features=auto, max_samples=2209, min_samples_leaf=10, min_samples_split=10, n_estimators=100; total time=   1.0s
# [CV 2/2] END max_depth=20, max_features=auto, max_samples=2209, min_samples_leaf=10, min_samples_split=10, n_estimators=100; total time=   1.0s
# [CV 1/2] END max_depth=20, max_features=auto, max_samples=2209, min_samples_leaf=10, min_samples_split=20, n_estimators=30; total time=   0.4s
# [CV 2/2] END max_depth=20, max_features=auto, max_samples=2209, min_samples_leaf=10, min_samples_split=20, n_estimators=30; total time=   0.4s
# [CV 1/2] END max_depth=20, max_features=auto, max_samples=2209, min_samples_leaf=10, min_samples_split=20, n_estimators=40; total time=   0.4s
# [CV 2/2] END max_depth=20, max_features=auto, max_samples=2209, min_samples_leaf=10, min_samples_split=20, n_estimators=40; total time=   0.5s
# [CV 1/2] END max_depth=20, max_features=auto, max_samples=2209, min_samples_leaf=10, min_samples_split=20, n_estimators=50; total time=   0.5s
# [CV 2/2] END max_depth=20, max_features=auto, max_samples=2209, min_samples_leaf=10, min_samples_split=20, n_estimators=50; total time=   0.5s
# [CV 1/2] END max_depth=20, max_features=auto, max_samples=2209, min_samples_leaf=10, min_samples_split=20, n_estimators=60; total time=   0.6s
# [CV 2/2] END max_depth=20, max_features=auto, max_samples=2209, min_samples_leaf=10, min_samples_split=20, n_estimators=60; total time=   0.6s
# [CV 1/2] END max_depth=20, max_features=auto, max_samples=2209, min_samples_leaf=10, min_samples_split=20, n_estimators=80; total time=   0.7s
# [CV 2/2] END max_depth=20, max_features=auto, max_samples=2209, min_samples_leaf=10, min_samples_split=20, n_estimators=80; total time=   0.8s
# [CV 1/2] END max_depth=20, max_features=auto, max_samples=2209, min_samples_leaf=10, min_samples_split=20, n_estimators=100; total time=   1.0s
# [CV 2/2] END max_depth=20, max_features=auto, max_samples=2209, min_samples_leaf=10, min_samples_split=20, n_estimators=100; total time=   1.0s
# [CV 1/2] END max_depth=20, max_features=auto, max_samples=2209, min_samples_leaf=10, min_samples_split=50, n_estimators=30; total time=   0.3s
# [CV 2/2] END max_depth=20, max_features=auto, max_samples=2209, min_samples_leaf=10, min_samples_split=50, n_estimators=30; total time=   0.3s
# [CV 1/2] END max_depth=20, max_features=auto, max_samples=2209, min_samples_leaf=10, min_samples_split=50, n_estimators=40; total time=   0.4s
# [CV 2/2] END max_depth=20, max_features=auto, max_samples=2209, min_samples_leaf=10, min_samples_split=50, n_estimators=40; total time=   0.4s
# [CV 1/2] END max_depth=20, max_features=auto, max_samples=2209, min_samples_leaf=10, min_samples_split=50, n_estimators=50; total time=   0.5s
# [CV 2/2] END max_depth=20, max_features=auto, max_samples=2209, min_samples_leaf=10, min_samples_split=50, n_estimators=50; total time=   0.5s
# [CV 1/2] END max_depth=20, max_features=auto, max_samples=2209, min_samples_leaf=10, min_samples_split=50, n_estimators=60; total time=   0.5s
# [CV 2/2] END max_depth=20, max_features=auto, max_samples=2209, min_samples_leaf=10, min_samples_split=50, n_estimators=60; total time=   0.6s
# [CV 1/2] END max_depth=20, max_features=auto, max_samples=2209, min_samples_leaf=10, min_samples_split=50, n_estimators=80; total time=   0.7s
# [CV 2/2] END max_depth=20, max_features=auto, max_samples=2209, min_samples_leaf=10, min_samples_split=50, n_estimators=80; total time=   0.7s
# [CV 1/2] END max_depth=20, max_features=auto, max_samples=2209, min_samples_leaf=10, min_samples_split=50, n_estimators=100; total time=   0.9s
# [CV 2/2] END max_depth=20, max_features=auto, max_samples=2209, min_samples_leaf=10, min_samples_split=50, n_estimators=100; total time=   0.9s
# [CV 1/2] END max_depth=30, max_features=auto, max_samples=2209, min_samples_leaf=1, min_samples_split=10, n_estimators=30; total time=   0.4s
# [CV 2/2] END max_depth=30, max_features=auto, max_samples=2209, min_samples_leaf=1, min_samples_split=10, n_estimators=30; total time=   0.4s
# [CV 1/2] END max_depth=30, max_features=auto, max_samples=2209, min_samples_leaf=1, min_samples_split=10, n_estimators=40; total time=   0.5s
# [CV 2/2] END max_depth=30, max_features=auto, max_samples=2209, min_samples_leaf=1, min_samples_split=10, n_estimators=40; total time=   0.5s
# [CV 1/2] END max_depth=30, max_features=auto, max_samples=2209, min_samples_leaf=1, min_samples_split=10, n_estimators=50; total time=   0.6s
# [CV 2/2] END max_depth=30, max_features=auto, max_samples=2209, min_samples_leaf=1, min_samples_split=10, n_estimators=50; total time=   0.6s
# [CV 1/2] END max_depth=30, max_features=auto, max_samples=2209, min_samples_leaf=1, min_samples_split=10, n_estimators=60; total time=   0.7s
# [CV 2/2] END max_depth=30, max_features=auto, max_samples=2209, min_samples_leaf=1, min_samples_split=10, n_estimators=60; total time=   0.8s
# [CV 1/2] END max_depth=30, max_features=auto, max_samples=2209, min_samples_leaf=1, min_samples_split=10, n_estimators=80; total time=   1.0s
# [CV 2/2] END max_depth=30, max_features=auto, max_samples=2209, min_samples_leaf=1, min_samples_split=10, n_estimators=80; total time=   0.9s
# [CV 1/2] END max_depth=30, max_features=auto, max_samples=2209, min_samples_leaf=1, min_samples_split=10, n_estimators=100; total time=   1.1s
# [CV 2/2] END max_depth=30, max_features=auto, max_samples=2209, min_samples_leaf=1, min_samples_split=10, n_estimators=100; total time=   1.0s
# [CV 1/2] END max_depth=30, max_features=auto, max_samples=2209, min_samples_leaf=1, min_samples_split=20, n_estimators=30; total time=   0.4s
# [CV 2/2] END max_depth=30, max_features=auto, max_samples=2209, min_samples_leaf=1, min_samples_split=20, n_estimators=30; total time=   0.3s
# [CV 1/2] END max_depth=30, max_features=auto, max_samples=2209, min_samples_leaf=1, min_samples_split=20, n_estimators=40; total time=   0.4s
# [CV 2/2] END max_depth=30, max_features=auto, max_samples=2209, min_samples_leaf=1, min_samples_split=20, n_estimators=40; total time=   0.5s
# [CV 1/2] END max_depth=30, max_features=auto, max_samples=2209, min_samples_leaf=1, min_samples_split=20, n_estimators=50; total time=   0.6s
# [CV 2/2] END max_depth=30, max_features=auto, max_samples=2209, min_samples_leaf=1, min_samples_split=20, n_estimators=50; total time=   0.6s
# [CV 1/2] END max_depth=30, max_features=auto, max_samples=2209, min_samples_leaf=1, min_samples_split=20, n_estimators=60; total time=   0.6s
# [CV 2/2] END max_depth=30, max_features=auto, max_samples=2209, min_samples_leaf=1, min_samples_split=20, n_estimators=60; total time=   0.6s
# [CV 1/2] END max_depth=30, max_features=auto, max_samples=2209, min_samples_leaf=1, min_samples_split=20, n_estimators=80; total time=   0.7s
# [CV 2/2] END max_depth=30, max_features=auto, max_samples=2209, min_samples_leaf=1, min_samples_split=20, n_estimators=80; total time=   0.8s
# [CV 1/2] END max_depth=30, max_features=auto, max_samples=2209, min_samples_leaf=1, min_samples_split=20, n_estimators=100; total time=   0.9s
# [CV 2/2] END max_depth=30, max_features=auto, max_samples=2209, min_samples_leaf=1, min_samples_split=20, n_estimators=100; total time=   1.0s
# [CV 1/2] END max_depth=30, max_features=auto, max_samples=2209, min_samples_leaf=1, min_samples_split=50, n_estimators=30; total time=   0.3s
# [CV 2/2] END max_depth=30, max_features=auto, max_samples=2209, min_samples_leaf=1, min_samples_split=50, n_estimators=30; total time=   0.3s
# [CV 1/2] END max_depth=30, max_features=auto, max_samples=2209, min_samples_leaf=1, min_samples_split=50, n_estimators=40; total time=   0.4s
# [CV 2/2] END max_depth=30, max_features=auto, max_samples=2209, min_samples_leaf=1, min_samples_split=50, n_estimators=40; total time=   0.4s
# [CV 1/2] END max_depth=30, max_features=auto, max_samples=2209, min_samples_leaf=1, min_samples_split=50, n_estimators=50; total time=   0.5s
# [CV 2/2] END max_depth=30, max_features=auto, max_samples=2209, min_samples_leaf=1, min_samples_split=50, n_estimators=50; total time=   0.5s
# [CV 1/2] END max_depth=30, max_features=auto, max_samples=2209, min_samples_leaf=1, min_samples_split=50, n_estimators=60; total time=   0.6s
# [CV 2/2] END max_depth=30, max_features=auto, max_samples=2209, min_samples_leaf=1, min_samples_split=50, n_estimators=60; total time=   0.5s
# [CV 1/2] END max_depth=30, max_features=auto, max_samples=2209, min_samples_leaf=1, min_samples_split=50, n_estimators=80; total time=   0.7s
# [CV 2/2] END max_depth=30, max_features=auto, max_samples=2209, min_samples_leaf=1, min_samples_split=50, n_estimators=80; total time=   0.7s
# [CV 1/2] END max_depth=30, max_features=auto, max_samples=2209, min_samples_leaf=1, min_samples_split=50, n_estimators=100; total time=   0.9s
# [CV 2/2] END max_depth=30, max_features=auto, max_samples=2209, min_samples_leaf=1, min_samples_split=50, n_estimators=100; total time=   1.1s
# [CV 1/2] END max_depth=30, max_features=auto, max_samples=2209, min_samples_leaf=5, min_samples_split=10, n_estimators=30; total time=   0.6s
# [CV 2/2] END max_depth=30, max_features=auto, max_samples=2209, min_samples_leaf=5, min_samples_split=10, n_estimators=30; total time=   0.6s
# [CV 1/2] END max_depth=30, max_features=auto, max_samples=2209, min_samples_leaf=5, min_samples_split=10, n_estimators=40; total time=   0.5s
# [CV 2/2] END max_depth=30, max_features=auto, max_samples=2209, min_samples_leaf=5, min_samples_split=10, n_estimators=40; total time=   0.7s
# [CV 1/2] END max_depth=30, max_features=auto, max_samples=2209, min_samples_leaf=5, min_samples_split=10, n_estimators=50; total time=   1.0s
# [CV 2/2] END max_depth=30, max_features=auto, max_samples=2209, min_samples_leaf=5, min_samples_split=10, n_estimators=50; total time=   0.8s
# [CV 1/2] END max_depth=30, max_features=auto, max_samples=2209, min_samples_leaf=5, min_samples_split=10, n_estimators=60; total time=   0.9s
# [CV 2/2] END max_depth=30, max_features=auto, max_samples=2209, min_samples_leaf=5, min_samples_split=10, n_estimators=60; total time=   1.1s
# [CV 1/2] END max_depth=30, max_features=auto, max_samples=2209, min_samples_leaf=5, min_samples_split=10, n_estimators=80; total time=   2.0s
# [CV 2/2] END max_depth=30, max_features=auto, max_samples=2209, min_samples_leaf=5, min_samples_split=10, n_estimators=80; total time=   2.0s
# [CV 1/2] END max_depth=30, max_features=auto, max_samples=2209, min_samples_leaf=5, min_samples_split=10, n_estimators=100; total time=   1.7s
# [CV 2/2] END max_depth=30, max_features=auto, max_samples=2209, min_samples_leaf=5, min_samples_split=10, n_estimators=100; total time=   1.3s
# [CV 1/2] END max_depth=30, max_features=auto, max_samples=2209, min_samples_leaf=5, min_samples_split=20, n_estimators=30; total time=   0.4s
# [CV 2/2] END max_depth=30, max_features=auto, max_samples=2209, min_samples_leaf=5, min_samples_split=20, n_estimators=30; total time=   0.4s
# [CV 1/2] END max_depth=30, max_features=auto, max_samples=2209, min_samples_leaf=5, min_samples_split=20, n_estimators=40; total time=   0.4s
# [CV 2/2] END max_depth=30, max_features=auto, max_samples=2209, min_samples_leaf=5, min_samples_split=20, n_estimators=40; total time=   0.4s
# [CV 1/2] END max_depth=30, max_features=auto, max_samples=2209, min_samples_leaf=5, min_samples_split=20, n_estimators=50; total time=   0.5s
# [CV 2/2] END max_depth=30, max_features=auto, max_samples=2209, min_samples_leaf=5, min_samples_split=20, n_estimators=50; total time=   0.6s
# [CV 1/2] END max_depth=30, max_features=auto, max_samples=2209, min_samples_leaf=5, min_samples_split=20, n_estimators=60; total time=   0.7s
# [CV 2/2] END max_depth=30, max_features=auto, max_samples=2209, min_samples_leaf=5, min_samples_split=20, n_estimators=60; total time=   0.7s
# [CV 1/2] END max_depth=30, max_features=auto, max_samples=2209, min_samples_leaf=5, min_samples_split=20, n_estimators=80; total time=   0.9s
# [CV 2/2] END max_depth=30, max_features=auto, max_samples=2209, min_samples_leaf=5, min_samples_split=20, n_estimators=80; total time=   0.8s
# [CV 1/2] END max_depth=30, max_features=auto, max_samples=2209, min_samples_leaf=5, min_samples_split=20, n_estimators=100; total time=   1.1s
# [CV 2/2] END max_depth=30, max_features=auto, max_samples=2209, min_samples_leaf=5, min_samples_split=20, n_estimators=100; total time=   1.1s
# [CV 1/2] END max_depth=30, max_features=auto, max_samples=2209, min_samples_leaf=5, min_samples_split=50, n_estimators=30; total time=   0.4s
# [CV 2/2] END max_depth=30, max_features=auto, max_samples=2209, min_samples_leaf=5, min_samples_split=50, n_estimators=30; total time=   0.3s
# [CV 1/2] END max_depth=30, max_features=auto, max_samples=2209, min_samples_leaf=5, min_samples_split=50, n_estimators=40; total time=   0.4s
# [CV 2/2] END max_depth=30, max_features=auto, max_samples=2209, min_samples_leaf=5, min_samples_split=50, n_estimators=40; total time=   0.4s
# [CV 1/2] END max_depth=30, max_features=auto, max_samples=2209, min_samples_leaf=5, min_samples_split=50, n_estimators=50; total time=   0.5s
# [CV 2/2] END max_depth=30, max_features=auto, max_samples=2209, min_samples_leaf=5, min_samples_split=50, n_estimators=50; total time=   0.5s
# [CV 1/2] END max_depth=30, max_features=auto, max_samples=2209, min_samples_leaf=5, min_samples_split=50, n_estimators=60; total time=   0.6s
# [CV 2/2] END max_depth=30, max_features=auto, max_samples=2209, min_samples_leaf=5, min_samples_split=50, n_estimators=60; total time=   0.7s
# [CV 1/2] END max_depth=30, max_features=auto, max_samples=2209, min_samples_leaf=5, min_samples_split=50, n_estimators=80; total time=   1.0s
# [CV 2/2] END max_depth=30, max_features=auto, max_samples=2209, min_samples_leaf=5, min_samples_split=50, n_estimators=80; total time=   0.9s
# [CV 1/2] END max_depth=30, max_features=auto, max_samples=2209, min_samples_leaf=5, min_samples_split=50, n_estimators=100; total time=   1.6s
# [CV 2/2] END max_depth=30, max_features=auto, max_samples=2209, min_samples_leaf=5, min_samples_split=50, n_estimators=100; total time=   1.5s
# [CV 1/2] END max_depth=30, max_features=auto, max_samples=2209, min_samples_leaf=10, min_samples_split=10, n_estimators=30; total time=   0.7s
# [CV 2/2] END max_depth=30, max_features=auto, max_samples=2209, min_samples_leaf=10, min_samples_split=10, n_estimators=30; total time=   0.5s
# [CV 1/2] END max_depth=30, max_features=auto, max_samples=2209, min_samples_leaf=10, min_samples_split=10, n_estimators=40; total time=   0.8s
# [CV 2/2] END max_depth=30, max_features=auto, max_samples=2209, min_samples_leaf=10, min_samples_split=10, n_estimators=40; total time=   0.6s
# [CV 1/2] END max_depth=30, max_features=auto, max_samples=2209, min_samples_leaf=10, min_samples_split=10, n_estimators=50; total time=   0.7s
# [CV 2/2] END max_depth=30, max_features=auto, max_samples=2209, min_samples_leaf=10, min_samples_split=10, n_estimators=50; total time=   0.9s
# [CV 1/2] END max_depth=30, max_features=auto, max_samples=2209, min_samples_leaf=10, min_samples_split=10, n_estimators=60; total time=   0.9s
# [CV 2/2] END max_depth=30, max_features=auto, max_samples=2209, min_samples_leaf=10, min_samples_split=10, n_estimators=60; total time=   0.7s
# [CV 1/2] END max_depth=30, max_features=auto, max_samples=2209, min_samples_leaf=10, min_samples_split=10, n_estimators=80; total time=   0.9s
# [CV 2/2] END max_depth=30, max_features=auto, max_samples=2209, min_samples_leaf=10, min_samples_split=10, n_estimators=80; total time=   1.0s
# [CV 1/2] END max_depth=30, max_features=auto, max_samples=2209, min_samples_leaf=10, min_samples_split=10, n_estimators=100; total time=   1.3s
# [CV 2/2] END max_depth=30, max_features=auto, max_samples=2209, min_samples_leaf=10, min_samples_split=10, n_estimators=100; total time=   1.2s
# [CV 1/2] END max_depth=30, max_features=auto, max_samples=2209, min_samples_leaf=10, min_samples_split=20, n_estimators=30; total time=   0.8s
# [CV 2/2] END max_depth=30, max_features=auto, max_samples=2209, min_samples_leaf=10, min_samples_split=20, n_estimators=30; total time=   0.5s
# [CV 1/2] END max_depth=30, max_features=auto, max_samples=2209, min_samples_leaf=10, min_samples_split=20, n_estimators=40; total time=   0.9s
# [CV 2/2] END max_depth=30, max_features=auto, max_samples=2209, min_samples_leaf=10, min_samples_split=20, n_estimators=40; total time=   0.6s
# [CV 1/2] END max_depth=30, max_features=auto, max_samples=2209, min_samples_leaf=10, min_samples_split=20, n_estimators=50; total time=   0.9s
# [CV 2/2] END max_depth=30, max_features=auto, max_samples=2209, min_samples_leaf=10, min_samples_split=20, n_estimators=50; total time=   1.0s
# [CV 1/2] END max_depth=30, max_features=auto, max_samples=2209, min_samples_leaf=10, min_samples_split=20, n_estimators=60; total time=   0.8s
# [CV 2/2] END max_depth=30, max_features=auto, max_samples=2209, min_samples_leaf=10, min_samples_split=20, n_estimators=60; total time=   0.9s
# [CV 1/2] END max_depth=30, max_features=auto, max_samples=2209, min_samples_leaf=10, min_samples_split=20, n_estimators=80; total time=   1.5s
# [CV 2/2] END max_depth=30, max_features=auto, max_samples=2209, min_samples_leaf=10, min_samples_split=20, n_estimators=80; total time=   1.5s
# [CV 1/2] END max_depth=30, max_features=auto, max_samples=2209, min_samples_leaf=10, min_samples_split=20, n_estimators=100; total time=   1.9s
# [CV 2/2] END max_depth=30, max_features=auto, max_samples=2209, min_samples_leaf=10, min_samples_split=20, n_estimators=100; total time=   1.5s
# [CV 1/2] END max_depth=30, max_features=auto, max_samples=2209, min_samples_leaf=10, min_samples_split=50, n_estimators=30; total time=   0.4s
# [CV 2/2] END max_depth=30, max_features=auto, max_samples=2209, min_samples_leaf=10, min_samples_split=50, n_estimators=30; total time=   0.4s
# [CV 1/2] END max_depth=30, max_features=auto, max_samples=2209, min_samples_leaf=10, min_samples_split=50, n_estimators=40; total time=   0.6s
# [CV 2/2] END max_depth=30, max_features=auto, max_samples=2209, min_samples_leaf=10, min_samples_split=50, n_estimators=40; total time=   0.5s
# [CV 1/2] END max_depth=30, max_features=auto, max_samples=2209, min_samples_leaf=10, min_samples_split=50, n_estimators=50; total time=   0.6s
# [CV 2/2] END max_depth=30, max_features=auto, max_samples=2209, min_samples_leaf=10, min_samples_split=50, n_estimators=50; total time=   0.6s
# [CV 1/2] END max_depth=30, max_features=auto, max_samples=2209, min_samples_leaf=10, min_samples_split=50, n_estimators=60; total time=   0.7s
# [CV 2/2] END max_depth=30, max_features=auto, max_samples=2209, min_samples_leaf=10, min_samples_split=50, n_estimators=60; total time=   0.7s
# [CV 1/2] END max_depth=30, max_features=auto, max_samples=2209, min_samples_leaf=10, min_samples_split=50, n_estimators=80; total time=   0.9s
# [CV 2/2] END max_depth=30, max_features=auto, max_samples=2209, min_samples_leaf=10, min_samples_split=50, n_estimators=80; total time=   1.0s
# [CV 1/2] END max_depth=30, max_features=auto, max_samples=2209, min_samples_leaf=10, min_samples_split=50, n_estimators=100; total time=   1.4s
# [CV 2/2] END max_depth=30, max_features=auto, max_samples=2209, min_samples_leaf=10, min_samples_split=50, n_estimators=100; total time=   1.4s
# [CV 1/2] END max_depth=40, max_features=auto, max_samples=2209, min_samples_leaf=1, min_samples_split=10, n_estimators=30; total time=   0.6s
# [CV 2/2] END max_depth=40, max_features=auto, max_samples=2209, min_samples_leaf=1, min_samples_split=10, n_estimators=30; total time=   0.5s
# [CV 1/2] END max_depth=40, max_features=auto, max_samples=2209, min_samples_leaf=1, min_samples_split=10, n_estimators=40; total time=   0.7s
# [CV 2/2] END max_depth=40, max_features=auto, max_samples=2209, min_samples_leaf=1, min_samples_split=10, n_estimators=40; total time=   0.8s
# [CV 1/2] END max_depth=40, max_features=auto, max_samples=2209, min_samples_leaf=1, min_samples_split=10, n_estimators=50; total time=   0.7s
# [CV 2/2] END max_depth=40, max_features=auto, max_samples=2209, min_samples_leaf=1, min_samples_split=10, n_estimators=50; total time=   1.0s
# [CV 1/2] END max_depth=40, max_features=auto, max_samples=2209, min_samples_leaf=1, min_samples_split=10, n_estimators=60; total time=   0.9s
# [CV 2/2] END max_depth=40, max_features=auto, max_samples=2209, min_samples_leaf=1, min_samples_split=10, n_estimators=60; total time=   0.9s
# [CV 1/2] END max_depth=40, max_features=auto, max_samples=2209, min_samples_leaf=1, min_samples_split=10, n_estimators=80; total time=   1.3s
# [CV 2/2] END max_depth=40, max_features=auto, max_samples=2209, min_samples_leaf=1, min_samples_split=10, n_estimators=80; total time=   1.5s
# [CV 1/2] END max_depth=40, max_features=auto, max_samples=2209, min_samples_leaf=1, min_samples_split=10, n_estimators=100; total time=   2.3s
# [CV 2/2] END max_depth=40, max_features=auto, max_samples=2209, min_samples_leaf=1, min_samples_split=10, n_estimators=100; total time=   2.0s
# ...
# [CV 1/2] END max_depth=40, max_features=auto, max_samples=2209, min_samples_leaf=10, min_samples_split=50, n_estimators=100; total time=   0.9s
# [CV 2/2] END max_depth=40, max_features=auto, max_samples=2209, min_samples_leaf=10, min_samples_split=50, n_estimators=100; total time=   0.8s
# [CV 1/2] END max_depth=50, max_features=auto, max_samples=2209, min_samples_leaf=1, min_samples_split=10, n_estimators=30; total time=   0.4s
# [CV 2/2] END max_depth=50, max_features=auto, max_samples=2209, min_samples_leaf=1, min_samples_split=10, n_estimators=30; total time=   0.4s
# [CV 1/2] END max_depth=50, max_features=auto, max_samples=2209, min_samples_leaf=1, min_samples_split=10, n_estimators=40; total time=   0.6s
# [CV 2/2] END max_depth=50, max_features=auto, max_samples=2209, min_samples_leaf=1, min_samples_split=10, n_estimators=40; total time=   0.5s
# [CV 1/2] END max_depth=50, max_features=auto, max_samples=2209, min_samples_leaf=1, min_samples_split=10, n_estimators=50; total time=   0.7s
# [CV 2/2] END max_depth=50, max_features=auto, max_samples=2209, min_samples_leaf=1, min_samples_split=10, n_estimators=50; total time=   0.7s
# [CV 1/2] END max_depth=50, max_features=auto, max_samples=2209, min_samples_leaf=1, min_samples_split=10, n_estimators=60; total time=   0.8s
# [CV 2/2] END max_depth=50, max_features=auto, max_samples=2209, min_samples_leaf=1, min_samples_split=10, n_estimators=60; total time=   0.8s
# [CV 1/2] END max_depth=50, max_features=auto, max_samples=2209, min_samples_leaf=1, min_samples_split=10, n_estimators=80; total time=   1.0s
# [CV 2/2] END max_depth=50, max_features=auto, max_samples=2209, min_samples_leaf=1, min_samples_split=10, n_estimators=80; total time=   1.1s
# [CV 1/2] END max_depth=50, max_features=auto, max_samples=2209, min_samples_leaf=1, min_samples_split=10, n_estimators=100; total time=   1.4s
# [CV 2/2] END max_depth=50, max_features=auto, max_samples=2209, min_samples_leaf=1, min_samples_split=10, n_estimators=100; total time=   1.3s
# [CV 1/2] END max_depth=50, max_features=auto, max_samples=2209, min_samples_leaf=1, min_samples_split=20, n_estimators=30; total time=   0.5s
# [CV 2/2] END max_depth=50, max_features=auto, max_samples=2209, min_samples_leaf=1, min_samples_split=20, n_estimators=30; total time=   0.4s
# [CV 1/2] END max_depth=50, max_features=auto, max_samples=2209, min_samples_leaf=1, min_samples_split=20, n_estimators=40; total time=   0.5s
# [CV 2/2] END max_depth=50, max_features=auto, max_samples=2209, min_samples_leaf=1, min_samples_split=20, n_estimators=40; total time=   0.6s
# [CV 1/2] END max_depth=50, max_features=auto, max_samples=2209, min_samples_leaf=1, min_samples_split=20, n_estimators=50; total time=   0.6s
# [CV 2/2] END max_depth=50, max_features=auto, max_samples=2209, min_samples_leaf=1, min_samples_split=20, n_estimators=50; total time=   0.6s
# [CV 1/2] END max_depth=50, max_features=auto, max_samples=2209, min_samples_leaf=1, min_samples_split=20, n_estimators=60; total time=   0.7s
# [CV 2/2] END max_depth=50, max_features=auto, max_samples=2209, min_samples_leaf=1, min_samples_split=20, n_estimators=60; total time=   0.7s
# [CV 1/2] END max_depth=50, max_features=auto, max_samples=2209, min_samples_leaf=1, min_samples_split=20, n_estimators=80; total time=   0.9s
# [CV 2/2] END max_depth=50, max_features=auto, max_samples=2209, min_samples_leaf=1, min_samples_split=20, n_estimators=80; total time=   0.9s
# [CV 1/2] END max_depth=50, max_features=auto, max_samples=2209, min_samples_leaf=1, min_samples_split=20, n_estimators=100; total time=   1.1s
# [CV 2/2] END max_depth=50, max_features=auto, max_samples=2209, min_samples_leaf=1, min_samples_split=20, n_estimators=100; total time=   1.0s
# [CV 1/2] END max_depth=50, max_features=auto, max_samples=2209, min_samples_leaf=1, min_samples_split=50, n_estimators=30; total time=   0.4s
# [CV 2/2] END max_depth=50, max_features=auto, max_samples=2209, min_samples_leaf=1, min_samples_split=50, n_estimators=30; total time=   0.4s
# [CV 1/2] END max_depth=50, max_features=auto, max_samples=2209, min_samples_leaf=1, min_samples_split=50, n_estimators=40; total time=   0.4s
# [CV 2/2] END max_depth=50, max_features=auto, max_samples=2209, min_samples_leaf=1, min_samples_split=50, n_estimators=40; total time=   0.4s
# [CV 1/2] END max_depth=50, max_features=auto, max_samples=2209, min_samples_leaf=1, min_samples_split=50, n_estimators=50; total time=   0.5s
# [CV 2/2] END max_depth=50, max_features=auto, max_samples=2209, min_samples_leaf=1, min_samples_split=50, n_estimators=50; total time=   0.5s
# [CV 1/2] END max_depth=50, max_features=auto, max_samples=2209, min_samples_leaf=1, min_samples_split=50, n_estimators=60; total time=   0.6s
# [CV 2/2] END max_depth=50, max_features=auto, max_samples=2209, min_samples_leaf=1, min_samples_split=50, n_estimators=60; total time=   0.6s
# [CV 1/2] END max_depth=50, max_features=auto, max_samples=2209, min_samples_leaf=1, min_samples_split=50, n_estimators=80; total time=   0.8s
# [CV 2/2] END max_depth=50, max_features=auto, max_samples=2209, min_samples_leaf=1, min_samples_split=50, n_estimators=80; total time=   0.7s
# [CV 1/2] END max_depth=50, max_features=auto, max_samples=2209, min_samples_leaf=1, min_samples_split=50, n_estimators=100; total time=   1.0s
# [CV 2/2] END max_depth=50, max_features=auto, max_samples=2209, min_samples_leaf=1, min_samples_split=50, n_estimators=100; total time=   0.9s
# [CV 1/2] END max_depth=50, max_features=auto, max_samples=2209, min_samples_leaf=5, min_samples_split=10, n_estimators=30; total time=   0.3s
# [CV 2/2] END max_depth=50, max_features=auto, max_samples=2209, min_samples_leaf=5, min_samples_split=10, n_estimators=30; total time=   0.4s
# [CV 1/2] END max_depth=50, max_features=auto, max_samples=2209, min_samples_leaf=5, min_samples_split=10, n_estimators=40; total time=   0.5s
# [CV 2/2] END max_depth=50, max_features=auto, max_samples=2209, min_samples_leaf=5, min_samples_split=10, n_estimators=40; total time=   0.4s
# [CV 1/2] END max_depth=50, max_features=auto, max_samples=2209, min_samples_leaf=5, min_samples_split=10, n_estimators=50; total time=   0.5s
# [CV 2/2] END max_depth=50, max_features=auto, max_samples=2209, min_samples_leaf=5, min_samples_split=10, n_estimators=50; total time=   0.5s
# [CV 1/2] END max_depth=50, max_features=auto, max_samples=2209, min_samples_leaf=5, min_samples_split=10, n_estimators=60; total time=   0.7s
# [CV 2/2] END max_depth=50, max_features=auto, max_samples=2209, min_samples_leaf=5, min_samples_split=10, n_estimators=60; total time=   0.7s
# [CV 1/2] END max_depth=50, max_features=auto, max_samples=2209, min_samples_leaf=5, min_samples_split=10, n_estimators=80; total time=   0.8s
# [CV 2/2] END max_depth=50, max_features=auto, max_samples=2209, min_samples_leaf=5, min_samples_split=10, n_estimators=80; total time=   0.8s
# [CV 1/2] END max_depth=50, max_features=auto, max_samples=2209, min_samples_leaf=5, min_samples_split=10, n_estimators=100; total time=   1.0s
# [CV 2/2] END max_depth=50, max_features=auto, max_samples=2209, min_samples_leaf=5, min_samples_split=10, n_estimators=100; total time=   1.0s
# [CV 1/2] END max_depth=50, max_features=auto, max_samples=2209, min_samples_leaf=5, min_samples_split=20, n_estimators=30; total time=   0.4s
# [CV 2/2] END max_depth=50, max_features=auto, max_samples=2209, min_samples_leaf=5, min_samples_split=20, n_estimators=30; total time=   0.4s
# [CV 1/2] END max_depth=50, max_features=auto, max_samples=2209, min_samples_leaf=5, min_samples_split=20, n_estimators=40; total time=   0.5s
# [CV 2/2] END max_depth=50, max_features=auto, max_samples=2209, min_samples_leaf=5, min_samples_split=20, n_estimators=40; total time=   0.5s
# [CV 1/2] END max_depth=50, max_features=auto, max_samples=2209, min_samples_leaf=5, min_samples_split=20, n_estimators=50; total time=   0.5s
# [CV 2/2] END max_depth=50, max_features=auto, max_samples=2209, min_samples_leaf=5, min_samples_split=20, n_estimators=50; total time=   0.5s
# [CV 1/2] END max_depth=50, max_features=auto, max_samples=2209, min_samples_leaf=5, min_samples_split=20, n_estimators=60; total time=   0.6s
# [CV 2/2] END max_depth=50, max_features=auto, max_samples=2209, min_samples_leaf=5, min_samples_split=20, n_estimators=60; total time=   0.6s
# [CV 1/2] END max_depth=50, max_features=auto, max_samples=2209, min_samples_leaf=5, min_samples_split=20, n_estimators=80; total time=   0.8s
# [CV 2/2] END max_depth=50, max_features=auto, max_samples=2209, min_samples_leaf=5, min_samples_split=20, n_estimators=80; total time=   0.8s
# [CV 1/2] END max_depth=50, max_features=auto, max_samples=2209, min_samples_leaf=5, min_samples_split=20, n_estimators=100; total time=   1.0s
# [CV 2/2] END max_depth=50, max_features=auto, max_samples=2209, min_samples_leaf=5, min_samples_split=20, n_estimators=100; total time=   1.0s
# [CV 1/2] END max_depth=50, max_features=auto, max_samples=2209, min_samples_leaf=5, min_samples_split=50, n_estimators=30; total time=   0.3s
# [CV 2/2] END max_depth=50, max_features=auto, max_samples=2209, min_samples_leaf=5, min_samples_split=50, n_estimators=30; total time=   0.3s
# [CV 1/2] END max_depth=50, max_features=auto, max_samples=2209, min_samples_leaf=5, min_samples_split=50, n_estimators=40; total time=   0.4s
# [CV 2/2] END max_depth=50, max_features=auto, max_samples=2209, min_samples_leaf=5, min_samples_split=50, n_estimators=40; total time=   0.4s
# [CV 1/2] END max_depth=50, max_features=auto, max_samples=2209, min_samples_leaf=5, min_samples_split=50, n_estimators=50; total time=   0.5s
# [CV 2/2] END max_depth=50, max_features=auto, max_samples=2209, min_samples_leaf=5, min_samples_split=50, n_estimators=50; total time=   0.5s
# [CV 1/2] END max_depth=50, max_features=auto, max_samples=2209, min_samples_leaf=5, min_samples_split=50, n_estimators=60; total time=   0.6s
# [CV 2/2] END max_depth=50, max_features=auto, max_samples=2209, min_samples_leaf=5, min_samples_split=50, n_estimators=60; total time=   0.6s
# [CV 1/2] END max_depth=50, max_features=auto, max_samples=2209, min_samples_leaf=5, min_samples_split=50, n_estimators=80; total time=   0.8s
# [CV 2/2] END max_depth=50, max_features=auto, max_samples=2209, min_samples_leaf=5, min_samples_split=50, n_estimators=80; total time=   0.7s
# [CV 1/2] END max_depth=50, max_features=auto, max_samples=2209, min_samples_leaf=5, min_samples_split=50, n_estimators=100; total time=   0.9s
# [CV 2/2] END max_depth=50, max_features=auto, max_samples=2209, min_samples_leaf=5, min_samples_split=50, n_estimators=100; total time=   0.9s
# [CV 1/2] END max_depth=50, max_features=auto, max_samples=2209, min_samples_leaf=10, min_samples_split=10, n_estimators=30; total time=   0.3s
# [CV 2/2] END max_depth=50, max_features=auto, max_samples=2209, min_samples_leaf=10, min_samples_split=10, n_estimators=30; total time=   0.3s
# [CV 1/2] END max_depth=50, max_features=auto, max_samples=2209, min_samples_leaf=10, min_samples_split=10, n_estimators=40; total time=   0.4s
# [CV 2/2] END max_depth=50, max_features=auto, max_samples=2209, min_samples_leaf=10, min_samples_split=10, n_estimators=40; total time=   0.4s
# [CV 1/2] END max_depth=50, max_features=auto, max_samples=2209, min_samples_leaf=10, min_samples_split=10, n_estimators=50; total time=   0.5s
# [CV 2/2] END max_depth=50, max_features=auto, max_samples=2209, min_samples_leaf=10, min_samples_split=10, n_estimators=50; total time=   0.5s
# [CV 1/2] END max_depth=50, max_features=auto, max_samples=2209, min_samples_leaf=10, min_samples_split=10, n_estimators=60; total time=   0.6s
# [CV 2/2] END max_depth=50, max_features=auto, max_samples=2209, min_samples_leaf=10, min_samples_split=10, n_estimators=60; total time=   0.6s
# [CV 1/2] END max_depth=50, max_features=auto, max_samples=2209, min_samples_leaf=10, min_samples_split=10, n_estimators=80; total time=   0.7s
# [CV 2/2] END max_depth=50, max_features=auto, max_samples=2209, min_samples_leaf=10, min_samples_split=10, n_estimators=80; total time=   0.8s
# [CV 1/2] END max_depth=50, max_features=auto, max_samples=2209, min_samples_leaf=10, min_samples_split=10, n_estimators=100; total time=   0.9s
# [CV 2/2] END max_depth=50, max_features=auto, max_samples=2209, min_samples_leaf=10, min_samples_split=10, n_estimators=100; total time=   0.9s
# [CV 1/2] END max_depth=50, max_features=auto, max_samples=2209, min_samples_leaf=10, min_samples_split=20, n_estimators=30; total time=   0.3s
# [CV 2/2] END max_depth=50, max_features=auto, max_samples=2209, min_samples_leaf=10, min_samples_split=20, n_estimators=30; total time=   0.3s
# [CV 1/2] END max_depth=50, max_features=auto, max_samples=2209, min_samples_leaf=10, min_samples_split=20, n_estimators=40; total time=   0.4s
# [CV 2/2] END max_depth=50, max_features=auto, max_samples=2209, min_samples_leaf=10, min_samples_split=20, n_estimators=40; total time=   0.5s
# [CV 1/2] END max_depth=50, max_features=auto, max_samples=2209, min_samples_leaf=10, min_samples_split=20, n_estimators=50; total time=   0.6s
# [CV 2/2] END max_depth=50, max_features=auto, max_samples=2209, min_samples_leaf=10, min_samples_split=20, n_estimators=50; total time=   0.5s
# [CV 1/2] END max_depth=50, max_features=auto, max_samples=2209, min_samples_leaf=10, min_samples_split=20, n_estimators=60; total time=   0.6s
# [CV 2/2] END max_depth=50, max_features=auto, max_samples=2209, min_samples_leaf=10, min_samples_split=20, n_estimators=60; total time=   0.6s
# [CV 1/2] END max_depth=50, max_features=auto, max_samples=2209, min_samples_leaf=10, min_samples_split=20, n_estimators=80; total time=   0.8s
# [CV 2/2] END max_depth=50, max_features=auto, max_samples=2209, min_samples_leaf=10, min_samples_split=20, n_estimators=80; total time=   0.7s
# [CV 1/2] END max_depth=50, max_features=auto, max_samples=2209, min_samples_leaf=10, min_samples_split=20, n_estimators=100; total time=   0.9s
# [CV 2/2] END max_depth=50, max_features=auto, max_samples=2209, min_samples_leaf=10, min_samples_split=20, n_estimators=100; total time=   0.9s
# [CV 1/2] END max_depth=50, max_features=auto, max_samples=2209, min_samples_leaf=10, min_samples_split=50, n_estimators=30; total time=   0.3s
# [CV 2/2] END max_depth=50, max_features=auto, max_samples=2209, min_samples_leaf=10, min_samples_split=50, n_estimators=30; total time=   0.3s
# [CV 1/2] END max_depth=50, max_features=auto, max_samples=2209, min_samples_leaf=10, min_samples_split=50, n_estimators=40; total time=   0.4s
# [CV 2/2] END max_depth=50, max_features=auto, max_samples=2209, min_samples_leaf=10, min_samples_split=50, n_estimators=40; total time=   0.4s
# [CV 1/2] END max_depth=50, max_features=auto, max_samples=2209, min_samples_leaf=10, min_samples_split=50, n_estimators=50; total time=   0.5s
# [CV 2/2] END max_depth=50, max_features=auto, max_samples=2209, min_samples_leaf=10, min_samples_split=50, n_estimators=50; total time=   0.5s
# [CV 1/2] END max_depth=50, max_features=auto, max_samples=2209, min_samples_leaf=10, min_samples_split=50, n_estimators=60; total time=   0.6s
# [CV 2/2] END max_depth=50, max_features=auto, max_samples=2209, min_samples_leaf=10, min_samples_split=50, n_estimators=60; total time=   0.6s
# [CV 1/2] END max_depth=50, max_features=auto, max_samples=2209, min_samples_leaf=10, min_samples_split=50, n_estimators=80; total time=   0.7s
# [CV 2/2] END max_depth=50, max_features=auto, max_samples=2209, min_samples_leaf=10, min_samples_split=50, n_estimators=80; total time=   0.7s
# [CV 1/2] END max_depth=50, max_features=auto, max_samples=2209, min_samples_leaf=10, min_samples_split=50, n_estimators=100; total time=   0.8s
# [CV 2/2] END max_depth=50, max_features=auto, max_samples=2209, min_samples_leaf=10, min_samples_split=50, n_estimators=100; total time=   0.8s
# {'max_depth': 40, 'max_features': 'auto', 'max_samples': 2209, 'min_samples_leaf': 1, 'min_samples_split': 10, 'n_estimators': 100}
# 0.8339842401649115
# --- 367.75133895874023 seconds ---

# %%
max_depth = 40 #CV_rfr.best_params_['max_depth'], # 30
n_estimators = 100 #CV_rfr.best_params_['n_estimators'])#100
min_samples_split = 10
min_samples_leaf = 1

regr = RandomForestRegressor(random_state = RANDOM_STATE,
                             max_depth = max_depth,
                             n_estimators = n_estimators,
                             min_samples_split = min_samples_split,
                             min_samples_leaf = min_samples_leaf,
                             n_jobs = n_jobs)
regr.fit(X_train, y_train)
# Out:
# RandomForestRegressor(max_depth=40, min_samples_split=10, n_jobs=8,
#                       random_state=42)

# %%
fn_model = '../models/spatial_RF_' + target +'_dep' + str(max_depth) \
                                            +'_ne' + str(n_estimators) \
                                            +'_splt' + str(min_samples_split) \
                                            +'_lf' + str(min_samples_leaf) +'.sav'
pickle.dump(regr, open(fn_model, 'wb'))

# %%
from sklearn.metrics import r2_score
train_score = r2_score(y_train,regr.predict(X_train))
test_score = r2_score(y_test,regr.predict(X_test))
    
y_line = np.linspace(np.min(y),np.max(y),100)

plt.rcParams["figure.figsize"] = (8, 8) # (w, h)
plt.rcParams.update({'font.size': 20})
fig, ax = plt.subplots()
plt.plot(y_line,y_line, '-k', label='y=x')
plt.scatter(y_train,regr.predict(X_train), s=2, c = 'blue',label = 'Train, R$^{2}$ ='+str(train_score)[:6])
plt.scatter(y_test,regr.predict(X_test), s=2, c = 'red', label = 'Test, R$^{2}$ ='+str(test_score)[:6])
plt.xlim((np.min(y),np.mean(y) + 5*np.std(y)))
plt.ylim((np.min(y),np.mean(y) + 5*np.std(y)))
ax.set_title('Predicted vs Actural for ' + target)
ax.set_xlabel('Actural Value')
ax.set_ylabel('Predicted Value')
plt.legend( loc='lower right')
plt.grid()
plt.tight_layout()

if not os.path.exists(dir_out + target):
    os.mkdir(dir_out + target)
plt.savefig(dir_out + target +'/spatial_RF_performance_'+target+'.png')

# %%
# Create object that can calculate shap values
explainer = shap.TreeExplainer(regr)
# Calculate shap_values
num_shap = 500
shap_values = explainer.shap_values(X_train[:num_shap])

# %%
# plot
shap.summary_plot(shap_values, X_train[:num_shap],
                  plot_size=(10,8),#'auto'
                  max_display = 30,
                  show=False
                 )
plt.tight_layout()
plt.savefig(dir_out + target + '/spatial_RF_shap_'+ target +'.png')
